# %% [markdown]
# # Topic: print()

# %% [markdown]
# 1) Using the python print function print any string value, integer value, boolean value, float value in single print command

# %%
print("Hello", 36, False, 27.8)
# Out:
# Hello 36 False 27.8

# %% [markdown]
# 2) Using the python print function print hyphon(-) separated any string value, integer value, boolean value, float value in single print command

# %%
print("Aarij", 334576, True, 27.8, sep='-')
# Out:
# Aarij-334576-True-27.8

# %% [markdown]
# 3) Using the python print function print any string value, integer value, boolean value, float value in separate print command.
# But every value must be space separated and in single line

# %%
print("hello" , end=" ")
print(22 , end=" ")
print(False , end=" ")
print(23.4)
# Out:
# hello 22 False 23.4

# %% [markdown]
# 4) Can a python print function take no value to print???

# %% [markdown]
# Yes it can

# %% [markdown]
# # TOPIC :Variables in Python Operators

# %% [markdown]
# 5) One of my friends name is Mr. Ahmed. He is 30 years old.  He is a lawer by profession. He has done his bachelors in law in the year 2005. He is working with a reputable law firm 'The Himalya Associates' in Karachi since 2015.
# He is a handsome lawer with height of 5.10 feets and weight 70600g. His monthly income is Rs. 200k PKR.
#
# Note: Create variables from above text and also assign values from the text.

# %%
name="Ahmed"
age=30
profession="lawyer"
passout_year=2005
employeer='The Himalya Associates'
year_joined=2015
height=5.10
weight_in_gram=70600
monthly_income=200000

# %% [markdown]
# 6)How many years has been to Mr. Ahmed after his bachelors degree? Create a variable that hold current year value and then subtract it from his passout year

# %%
current_year=2025
print(current_year-passout_year)
# Out:
# 20

# %% [markdown]
# 7) How many years has Mr. Ahmed been working with law firm 'The Himalya Associates'. Create necesary variables and print the correct number of years in working in the firm

# %%
print(current_year-year_joined)
# Out:
# 10

# %% [markdown]
# 8)Convert the monthly income of Mr. Ahmed in dollars.  Create necesary variables and print the income in dollars.

# %%
usd_in_pkr=280
salary_in_usd=monthly_income/usd_in_pkr
print(f"{salary_in_usd} USD")
# Out:
# 714.2857142857143 USD

# %% [markdown]
# 9) Check if the income in dollars is a float or integer value. if it is float, re-write the code so that income gets converted in integer. print the income in integer type value

# %%
print(type(salary_in_usd))
salary_in_usd=int(salary_in_usd)
print(type(salary_in_usd))
# Out:
# <class 'float'>
# <class 'int'>

# %% [raw]
# 10) Print the type of Mr. Ahmed's weight. Convert the weight of Mr. Ahmed in kg so that weight must be a integer value.

# %%
print(type(weight_in_gram))
weight_in_kg=weight_in_gram//1000
print(weight_in_kg)
print(type(weight_in_kg))
# Out:
# <class 'int'>
# 70
# <class 'int'>

# %% [markdown]
# #11) print the year of birth of Mr. Ahmed.

# %%
birth_year=current_year-age
print(birth_year)
# Out:
# 1995

# %% [markdown]
# 12) Can Rs. 100 be divided equally among 6 students?
# HINT: % operator (modulo)

# %%
print(10%6)
"""No, becaise we will get the remainder 4"""
# Out:
# 4
# 'No, becaise we will get the remainder 4'
